# %%
import pandas as pd
import numpy as np
from pickle import dump

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
import time

from sklearn.preprocessing import StandardScaler
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def search_song(artist, title):
    '''
    Query spotify API for a given song to obtain its URI.
    
    Args:
        artist: Artist of the song
        title: Song title
    Return:
        On success the URI is returned, on error "invalid"
    '''
    try:
        print(f'Query for "{title}" by "{artist}": ', end='')
        result = sp.search(q=f'track:{title} artist:{artist}', limit=1)
        uri = result['tracks']['items'][0]['uri']
        print(uri)
        return uri
    except:
        print('failed')
        return "invalid"

# %%
def get_audio_features(chunk):
    '''
    Get audiofeatures for given dataframe chunk and return them
    as a dictionary.
    
    Args:
        chunk: Pandas dataframe
    Return:
        Dictionary with audiofeatures
    '''

    d = {'danceability': [],
         'energy': [],
         'key': [],
         'loudness': [],
         'mode': [],
         'speechiness': [],
         'acousticness': [],
         'instrumentalness': [],
         'liveness': [],
         'valence': [],
         'tempo': [],
         'type': [],
         'id': [],
         'uri': [],
         'track_href': [],
         'analysis_url': [],
         'duration_ms': [],
         'time_signature': []
        }
    
    for index, row in chunk.iterrows():

        uri = search_song(row['artist'], row['title'])       
        audio_feat = sp.audio_features(uri)[0]        

        if audio_feat == None:
            # If we couldn't receive the audio features from spotify,
            # just store a 'x' for each feature and drop the song later...
            for key in d:
                d[key].append('x')
        else:        
            d['danceability'].append(audio_feat['danceability'])
            d['energy'].append(audio_feat['energy'])
            d['key'].append(audio_feat['key'])
            d['loudness'].append(audio_feat['loudness'])
            d['mode'].append(audio_feat['mode'])
            d['speechiness'].append(audio_feat['speechiness'])
            d['acousticness'].append(audio_feat['acousticness'])
            d['instrumentalness'].append(audio_feat['instrumentalness'])
            d['liveness'].append(audio_feat['liveness'])
            d['valence'].append(audio_feat['valence'])
            d['tempo'].append(audio_feat['tempo'])
            d['type'].append(audio_feat['type'])
            d['id'].append(audio_feat['id'])
            d['uri'].append(audio_feat['uri'])
            d['track_href'].append(audio_feat['track_href'])
            d['analysis_url'].append(audio_feat['analysis_url'])
            d['duration_ms'].append(audio_feat['duration_ms'])
            d['time_signature'].append(audio_feat['time_signature'])

        time.sleep(0.5)
    return d

# %% [markdown]
# ### Load our song dataset

# %%
songs_df = pd.read_csv('songs.csv')
songs_df
# Out:
#                    artist                           title  danceability  \
# 0            Taylor Swift                       Anti-Hero         0.637
# 1            Taylor Swift                   Lavender Haze         0.733
# 2            Taylor Swift                          Maroon         0.637
# 3            Taylor Swift                   Midnight Rain         0.643
# 4            Taylor Swift                       Bejeweled         0.700
# ...                   ...                             ...           ...
# 2294      Daniel Norgren                 Moonshine Got Me         0.458
# 2295                Dover                    Serenade me          0.524
# 2296                Queen                  I want it all          0.402
# 2297   Sultans of Ping FC             Where's me jumper?          0.395
# 2298        Jorge Cafrune  No soy de aquí ni soy de allá          0.555
#
#       energy  key  loudness  mode  speechiness  acousticness  \
# 0      0.643    4    -6.571     1       0.0519        0.1300
# 1      0.436   10   -10.489     1       0.0800        0.2580
# 2      0.398    7    -8.294     1       0.0564        0.0573
# 3      0.363    0   -11.738     1       0.0767        0.6900
# 4      0.550    7    -9.130     1       0.0653        0.0661
# ...      ...  ...       ...   ...          ...           ...
# 2294   0.497    8    -9.660     1       0.0479        0.7160
# 2295   0.776    5    -6.193     0       0.0404        0.0330
# 2296   0.835   11    -5.734     0       0.0500        0.0287
# 2297   0.914   11    -6.706     0       0.1590        0.0728
# 2298   0.153    1   -11.320     1       0.0419        0.9460
#
#       instrumentalness  ...  valence    tempo            type  \
# 0             0.000002  ...   0.5330   97.008  audio_features
# 1             0.000573  ...   0.0976   96.985  audio_features
# 2             0.000001  ...   0.0374  108.075  audio_features
# 3             0.000052  ...   0.2300  139.865  audio_features
# 4             0.000102  ...   0.4120  164.003  audio_features
# ...                ...  ...      ...      ...             ...
# 2294          0.155000  ...   0.1440  107.748  audio_features
# 2295          0.000022  ...   0.3010  123.622  audio_features
# 2296          0.000003  ...   0.4300   92.029  audio_features
# 2297          0.000000  ...   0.4350  174.284  audio_features
# 2298          0.000001  ...   0.2740  108.427  audio_features
#
#                           id                                   uri  \
# 0     0V3wPSX9ygBnCm8psDIegu  spotify:track:0V3wPSX9ygBnCm8psDIegu
# 1     5jQI2r1RdgtuT8S3iG8zFC  spotify:track:5jQI2r1RdgtuT8S3iG8zFC
# 2     3eX0NZfLtGzoLUxPNvRfqm  spotify:track:3eX0NZfLtGzoLUxPNvRfqm
# 3     3rWDp9tBPQR9z6U5YyRSK4  spotify:track:3rWDp9tBPQR9z6U5YyRSK4
# 4     0jvo9CjnbR0lYUDTSNTMiu  spotify:track:0jvo9CjnbR0lYUDTSNTMiu
# ...                      ...                                   ...
# 2294  6LrxNNCaqssGmyCGi1EPJA  spotify:track:6LrxNNCaqssGmyCGi1EPJA
# 2295  4tzi4VV1vCTZsT4SEKQIKJ  spotify:track:4tzi4VV1vCTZsT4SEKQIKJ
# 2296  5AaGovcNgVcreY5GHmv3u3  spotify:track:5AaGovcNgVcreY5GHmv3u3
# 2297  1PWkvrHtJI1TLfnZDWDf2u  spotify:track:1PWkvrHtJI1TLfnZDWDf2u
# 2298  0jpbBVTdq6njJi9xUq4Mli  spotify:track:0jpbBVTdq6njJi9xUq4Mli
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/0V3wPSX9ygBn...
# 1     https://api.spotify.com/v1/tracks/5jQI2r1Rdgtu...
# 2     https://api.spotify.com/v1/tracks/3eX0NZfLtGzo...
# 3     https://api.spotify.com/v1/tracks/3rWDp9tBPQR9...
# 4     https://api.spotify.com/v1/tracks/0jvo9CjnbR0l...
# ...                                                 ...
# 2294  https://api.spotify.com/v1/tracks/6LrxNNCaqssG...
# 2295  https://api.spotify.com/v1/tracks/4tzi4VV1vCTZ...
# 2296  https://api.spotify.com/v1/tracks/5AaGovcNgVcr...
# 2297  https://api.spotify.com/v1/tracks/1PWkvrHtJI1T...
# 2298  https://api.spotify.com/v1/tracks/0jpbBVTdq6nj...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/0V3w...      200690
# 1     https://api.spotify.com/v1/audio-analysis/5jQI...      202396
# 2     https://api.spotify.com/v1/audio-analysis/3eX0...      218271
# 3     https://api.spotify.com/v1/audio-analysis/3rWD...      174783
# 4     https://api.spotify.com/v1/audio-analysis/0jvo...      194166
# ...                                                 ...         ...
# 2294  https://api.spotify.com/v1/audio-analysis/6Lrx...      531333
# 2295  https://api.spotify.com/v1/audio-analysis/4tzi...      234280
# 2296  https://api.spotify.com/v1/audio-analysis/5AaG...      241253
# 2297  https://api.spotify.com/v1/audio-analysis/1PWk...      189213
# 2298  https://api.spotify.com/v1/audio-analysis/0jpb...      192293
#
#       time_signature  hot
# 0                  4    1
# 1                  4    1
# 2                  4    1
# 3                  4    1
# 4                  4    1
# ...              ...  ...
# 2294               4    0
# 2295               4    0
# 2296               4    0
# 2297               4    0
# 2298               4    0
#
# [2299 rows x 21 columns]

# %% [markdown]
# #### After discussing with the team we opted the following audio- features that would be helpful in clustering the data together :'danceability', 'energy, 'key', 'loudness, speechiness', acousticness', instrumentalness',liveness, 'valence',tempo'

# %% [markdown]
# #### fearing the time elapsed for computations, after much discussion with the team i have decided to create 5 clusters from the songs dataframe

# %% [markdown]
# #### Gaussian Mixture method assumes that the data is grouped in such a way that resembles gaussian distributions.

# %% [markdown]
# #### Training Methods:
#     1. Diagonal covariance, Tied Covariance
#     2. n_components: 5 and 7 #the number of clusters

# %% [markdown]
# Method1: covariance = 'diag',n_components = 5

# %%
def gmm_n5_diag(X,X_scaled_df):
    df = X.copy()
    gmm = GaussianMixture(n_components=5,init_params ="random", covariance_type='diag')
    gmm.fit(X_scaled_df)
    ygmm_hat1 = gmm.predict(X_scaled_df)
    df["gmm_n5_diag"] = ygmm_hat1
    dump(gmm, open('gmm_n5_diag.pickle', 'wb'))
    return df

# %% [markdown]
# Method2: covariance = 'diag',n_components = 7

# %%
def gmm_n7_diag(X,X_scaled_df):
    df = X.copy()
    gmm = GaussianMixture(n_components=7,init_params ="random", covariance_type='diag')
    gmm.fit(X_scaled_df)
    ygmm_hat2 = gmm.predict(X_scaled_df)
    df["gmm_n7_diag"] = ygmm_hat2
    dump(gmm, open('gmm_n7_diag.pickle', 'wb'))
    return df

# %% [markdown]
# Method3: covariance = 'tied',n_components = 5

# %%
def gmm_n5_tied(X,X_scaled_df):
    df = X.copy()
    gmm = GaussianMixture(n_components=5,init_params ="random", covariance_type='tied')
    gmm.fit(X_scaled_df)
    ygmm_hat3 = gmm.predict(X_scaled_df)
    df["gmm_n5_tied"] = ygmm_hat3
    dump(gmm, open('gmm_n5_tied.pickle','wb'))
    return df

# %% [markdown]
# Method4: covariance = 'tied' n_components = 7

# %%
def gmm_n7_tied(X,X_scaled_df):
    df = X.copy()
    gmm = GaussianMixture(n_components=7,init_params ="random", covariance_type='tied')
    gmm.fit(X_scaled_df)
    ygmm_hat4 = gmm.predict(X_scaled_df)
    df["gmm_n7_tied"] = ygmm_hat4
    dump(gmm, open('gmm_n7_tied.pickle','wb'))
    return df

# %% [markdown]
# #### I have selected to create a Gaussian mixtures model and compare it with my team members about their models and dicuss the optimal solution for the same

# %%
X = songs_df
X = X.select_dtypes(np.number)
X = X.drop(['mode', 'duration_ms', 'time_signature', 'hot'], axis=1)
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns) #convert back to df
dump(scaler, open('scaler.pickle', 'wb'))
print()
X_scaled_df.describe()
# Out:
#        danceability        energy           key      loudness   speechiness  \
# count  2.299000e+03  2.299000e+03  2.299000e+03  2.299000e+03  2.299000e+03
# mean   2.370874e-16 -1.380173e-16 -4.819498e-17 -1.568993e-16 -5.174441e-17
# std    1.000218e+00  1.000218e+00  1.000218e+00  1.000218e+00  1.000218e+00
# min   -3.707318e+00 -2.508808e+00 -1.422125e+00 -7.503691e+00 -9.781725e-01
# 25%   -6.366765e-01 -6.540799e-01 -8.615652e-01 -6.141429e-01 -4.667704e-01
# 50%    1.125599e-01  1.296079e-01 -2.072536e-02  1.132472e-01 -3.365076e-01
# 75%    7.266881e-01  7.913887e-01  8.201145e-01  7.404110e-01 -1.326279e-02
# max    2.304998e+00  1.749229e+00  1.660954e+00  2.149053e+00  1.216068e+01
#
#        acousticness  instrumentalness      liveness       valence  \
# count  2.299000e+03      2.299000e+03  2.299000e+03  2.299000e+03
# mean   1.748155e-17     -6.203051e-17 -4.568382e-17  2.711088e-16
# std    1.000218e+00      1.000218e+00  1.000218e+00  1.000218e+00
# min   -1.039773e+00     -3.241764e-01 -1.118125e+00 -2.397197e+00
# 25%   -8.899865e-01     -3.241764e-01 -6.302673e-01 -7.981902e-01
# 50%   -3.857045e-01     -3.240344e-01 -3.731269e-01  1.073194e-01
# 75%    8.072540e-01     -3.109722e-01  3.615597e-01  8.503525e-01
# max    2.062508e+00      4.952138e+00  5.175690e+00  1.510166e+00
#
#               tempo
# count  2.299000e+03
# mean   4.240724e-16
# std    1.000218e+00
# min   -4.404110e+00
# 25%   -7.052708e-01
# 50%   -4.918159e-02
# 75%    5.097789e-01
# max    3.441242e+00

# %% [markdown]
# Running the cluster predictions on Gaussian Mixtures

# %%
pred_n5_diag = gmm_n5_diag(X,X_scaled_df)
pred_n7_diag = gmm_n7_diag(X,X_scaled_df)
pred_n5_tied = gmm_n5_tied(X,X_scaled_df)
pred_n7_tied = gmm_n7_tied(X,X_scaled_df)
n5_diag = pred_n5_diag[['gmm_n5_diag']]
n7_diag = pred_n7_diag[['gmm_n7_diag']]
n5_tied = pred_n5_tied[['gmm_n5_tied']]
n7_tied = pred_n7_tied[['gmm_n7_tied']]
'''
combining all the clusters from the team members

'''
songs_df = pd.read_csv('songs_clustered_lukas.csv')
clustered_songs = pd.concat([songs_df,n5_diag,n7_diag,n5_tied,n7_tied], axis =1, sort=False)
clustered_songs.to_csv('songs_clustered.csv')
# Out:
#       Unnamed: 0               artist                           title  \
# 0              0         Taylor Swift                       Anti-Hero
# 1              1         Taylor Swift                   Lavender Haze
# 2              2         Taylor Swift                          Maroon
# 3              3         Taylor Swift                   Midnight Rain
# 4              4         Taylor Swift                       Bejeweled
# ...          ...                  ...                             ...
# 2294        2294      Daniel Norgren                 Moonshine Got Me
# 2295        2295                Dover                    Serenade me
# 2296        2296                Queen                  I want it all
# 2297        2297   Sultans of Ping FC             Where's me jumper?
# 2298        2298        Jorge Cafrune  No soy de aquí ni soy de allá
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.637   0.643    4    -6.571     1       0.0519        0.1300
# 1            0.733   0.436   10   -10.489     1       0.0800        0.2580
# 2            0.637   0.398    7    -8.294     1       0.0564        0.0573
# 3            0.643   0.363    0   -11.738     1       0.0767        0.6900
# 4            0.700   0.550    7    -9.130     1       0.0653        0.0661
# ...            ...     ...  ...       ...   ...          ...           ...
# 2294         0.458   0.497    8    -9.660     1       0.0479        0.7160
# 2295         0.524   0.776    5    -6.193     0       0.0404        0.0330
# 2296         0.402   0.835   11    -5.734     0       0.0500        0.0287
# 2297         0.395   0.914   11    -6.706     0       0.1590        0.0728
# 2298         0.555   0.153    1   -11.320     1       0.0419        0.9460
#
#       ...  duration_ms  time_signature  hot  cluster_kmeans_4  \
# 0     ...       200690               4    1                 1
# 1     ...       202396               4    1                 0
# 2     ...       218271               4    1                 3
# 3     ...       174783               4    1                 0
# 4     ...       194166               4    1                 3
# ...   ...          ...             ...  ...               ...
# 2294  ...       531333               4    0                 0
# 2295  ...       234280               4    0                 3
# 2296  ...       241253               4    0                 3
# 2297  ...       189213               4    0                 3
# 2298  ...       192293               4    0                 0
#
#      cluster_kmeans_11 cluster_kmeans_16 gmm_n5_diag gmm_n7_diag gmm_n5_tied  \
# 0                    4                 9           3           0           2
# 1                    9                 7           4           1           0
# 2                    9                 9           1           0           0
# 3                    1                 2           4           6           4
# 4                   10                12           3           0           1
# ...                ...               ...         ...         ...         ...
# 2294                 9                 7           0           4           2
# 2295                 9                 9           3           0           2
# 2296                 9                 9           3           6           1
# 2297                10                12           4           6           1
# 2298                 5                11           1           3           4
#
#       gmm_n7_tied
# 0               2
# 1               5
# 2               5
# 3               5
# 4               5
# ...           ...
# 2294            5
# 2295            5
# 2296            0
# 2297            4
# 2298            3
#
# [2299 rows x 29 columns]

# %% [markdown]
# #### Conclusion: the GMM with covariance diagnol and cluster size of 5 is more efficient. Next I will validate by grouping the cluster data together and lsiten to first few secnds of the songs

# %%
#concatenate the cluster to the final dataframe
clustered_df = gmm_n5_diag(X,X_scaled_df)
clustered_songs = pd.concat([songs_df, clustered_df], sort=False)
clustered_songs.head(30)
# Out:
#            artist                         title  danceability  energy  key  \
# 0    Taylor Swift                     Anti-Hero         0.637   0.643    4
# 1    Taylor Swift                 Lavender Haze         0.733   0.436   10
# 2    Taylor Swift                        Maroon         0.637   0.398    7
# 3    Taylor Swift                 Midnight Rain         0.643   0.363    0
# 4    Taylor Swift                     Bejeweled         0.700   0.550    7
# 5    Taylor Swift                  Question...?         0.751   0.502    7
# 6    Taylor Swift                         Karma         0.642   0.620    8
# 7    Taylor Swift                Vigilante Shit         0.798   0.277    4
# 8      Steve Lacy                     Bad Habit         0.686   0.507    1
# 9    Taylor Swift                    Mastermind         0.661   0.352    4
# 10   Taylor Swift                     Labyrinth         0.487   0.313    0
# 11   Taylor Swift                 Sweet Nothing         0.334   0.161    0
# 12   Harry Styles                     As It Was         0.520   0.731    6
# 13    OneRepublic               I Ain't Worried         0.704   0.797    0
# 14  Morgan Wallen                     You Proof         0.731   0.850    9
# 15   Taylor Swift     Bigger Than The Whole Sky         0.422   0.235    6
# 16    Nicki Minaj             Super Freaky Girl         0.950   0.891    2
# 17    Chris Brown           Under The Influence         0.733   0.690    9
# 18   Taylor Swift                 The Great War         0.573   0.741    5
# 19       Doja Cat                         Vegas         0.801   0.601    8
# 20     Zach Bryan       Something In The Orange         0.369   0.192    4
# 21  Morgan Wallen                 Wasted On You         0.505   0.657   11
# 22   Taylor Swift                         Paris         0.700   0.509    7
# 23   Taylor Swift               High Infidelity         0.646   0.529   10
# 24      Bad Bunny              Titi Me Pregunto         0.650   0.715    5
# 25          Lizzo               About Damn Time         0.836   0.743   10
# 26     Luke Combs      The Kind Of Love We Make         0.608   0.745    1
# 27   Harry Styles            Late Night Talking         0.714   0.728   10
# 28        Beyonce                       Cuff It         0.780   0.689    7
# 29  Cole Swindell  She Had Me At Heads Carolina         0.607   0.912    8
#
#     loudness  mode  speechiness  acousticness  instrumentalness  ...    tempo  \
# 0     -6.571   1.0       0.0519        0.1300          0.000002  ...   97.008
# 1    -10.489   1.0       0.0800        0.2580          0.000573  ...   96.985
# 2     -8.294   1.0       0.0564        0.0573          0.000001  ...  108.075
# 3    -11.738   1.0       0.0767        0.6900          0.000052  ...  139.865
# 4     -9.130   1.0       0.0653        0.0661          0.000102  ...  164.003
# 5     -8.777   1.0       0.1620        0.2260          0.000000  ...  108.989
# 6     -7.091   1.0       0.0666        0.0734          0.000000  ...   90.020
# 7    -11.096   0.0       0.3900        0.1730          0.000053  ...   79.846
# 8     -7.097   1.0       0.0357        0.6260          0.000075  ...  168.955
# 9    -14.077   1.0       0.1170        0.5710          0.001470  ...  125.934
# 10   -15.434   1.0       0.0487        0.7910          0.348000  ...  110.039
# 11   -14.875   1.0       0.0506        0.9670          0.000047  ...  176.747
# 12    -5.338   0.0       0.0557        0.3420          0.001010  ...  173.930
# 13    -5.927   1.0       0.0475        0.0826          0.000745  ...  139.994
# 14    -4.913   1.0       0.0336        0.2520          0.000000  ...  119.706
# 15   -12.379   1.0       0.0568        0.8260          0.006480  ...  165.710
# 16    -2.653   1.0       0.2410        0.0645          0.000018  ...  133.010
# 17    -5.529   0.0       0.0427        0.0635          0.000001  ...  116.992
# 18    -8.987   1.0       0.0353        0.2190          0.000022  ...   96.016
# 19    -7.574   0.0       0.2550        0.0777          0.000032  ...  159.969
# 20   -12.151   0.0       0.0400        0.5550          0.000008  ...  175.212
# 21    -5.240   0.0       0.0318        0.3730          0.001070  ...  196.000
# 22   -10.547   1.0       0.0789        0.1120          0.000033  ...  110.947
# 23   -10.179   1.0       0.0864        0.7230          0.000000  ...   87.862
# 24    -5.198   0.0       0.2530        0.0993          0.000291  ...  106.672
# 25    -6.305   0.0       0.0656        0.0995          0.000000  ...  108.966
# 26    -4.130   1.0       0.0277        0.0226          0.000006  ...  102.025
# 27    -4.595   1.0       0.0468        0.2980          0.000000  ...  114.996
# 28    -5.668   1.0       0.1410        0.0368          0.000010  ...  115.042
# 29    -3.449   1.0       0.0611        0.1240          0.000000  ...  134.944
#
#               type                      id  \
# 0   audio_features  0V3wPSX9ygBnCm8psDIegu
# 1   audio_features  5jQI2r1RdgtuT8S3iG8zFC
# 2   audio_features  3eX0NZfLtGzoLUxPNvRfqm
# 3   audio_features  3rWDp9tBPQR9z6U5YyRSK4
# 4   audio_features  0jvo9CjnbR0lYUDTSNTMiu
# 5   audio_features  6C7OF1Jal7YkyjzyUG8vkK
# 6   audio_features  7KokYm8cMIXCsGVmUvKtqf
# 7   audio_features  1xwAWUI6Dj0WGC3KiUPN0O
# 8   audio_features  5CM4UuQ9Gnd6K2YyKGPMoK
# 9   audio_features  56hioFjQ0DXrdn04hZcFgG
# 10  audio_features  43q586vP8gGkYypKoSddhl
# 11  audio_features  3zmwONxswBAzGwExPugSLN
# 12  audio_features  4LRPiXqCikLlN15c3yImP7
# 13  audio_features  4h9wh7iOZ0GGn8QVp4RAOB
# 14  audio_features  5uU1uuyaUIBOiiUSQG7Wl3
# 15  audio_features  0BiqmkasE5FdrChwKfVp8X
# 16  audio_features  4C6Uex2ILwJi9sZXRdmqXp
# 17  audio_features  5IgjP7X4th6nMNDh4akUHb
# 18  audio_features  3UMrglJeju5yWyYIW6o99b
# 19  audio_features  0hquQWY3xvYqN4qtiquniF
# 20  audio_features  3WMj8moIAXJhHsyLaqIIHI
# 21  audio_features  3cBsEDNhFI9E82vPj3kvi3
# 22  audio_features  7712gjoih4QoDbXpljEk21
# 23  audio_features  5kiZGSxgqPdv6rbqL9THdd
# 24  audio_features  1IHWl5LamUGEuP4ozKQSXZ
# 25  audio_features  1PckUlxKqWQs3RlWXVBLw3
# 26  audio_features  28n8z9IQKyjMPxmvYMBqZa
# 27  audio_features  1qEmFfgcLObUfQm0j1W2CK
# 28  audio_features  1xzi1Jcr7mEi9K2RfzLOqS
# 29  audio_features  200x8ONbPfFzByUr3fVz46
#
#                                      uri  \
# 0   spotify:track:0V3wPSX9ygBnCm8psDIegu
# 1   spotify:track:5jQI2r1RdgtuT8S3iG8zFC
# 2   spotify:track:3eX0NZfLtGzoLUxPNvRfqm
# 3   spotify:track:3rWDp9tBPQR9z6U5YyRSK4
# 4   spotify:track:0jvo9CjnbR0lYUDTSNTMiu
# 5   spotify:track:6C7OF1Jal7YkyjzyUG8vkK
# 6   spotify:track:7KokYm8cMIXCsGVmUvKtqf
# 7   spotify:track:1xwAWUI6Dj0WGC3KiUPN0O
# 8   spotify:track:5CM4UuQ9Gnd6K2YyKGPMoK
# 9   spotify:track:56hioFjQ0DXrdn04hZcFgG
# 10  spotify:track:43q586vP8gGkYypKoSddhl
# 11  spotify:track:3zmwONxswBAzGwExPugSLN
# 12  spotify:track:4LRPiXqCikLlN15c3yImP7
# 13  spotify:track:4h9wh7iOZ0GGn8QVp4RAOB
# 14  spotify:track:5uU1uuyaUIBOiiUSQG7Wl3
# 15  spotify:track:0BiqmkasE5FdrChwKfVp8X
# 16  spotify:track:4C6Uex2ILwJi9sZXRdmqXp
# 17  spotify:track:5IgjP7X4th6nMNDh4akUHb
# 18  spotify:track:3UMrglJeju5yWyYIW6o99b
# 19  spotify:track:0hquQWY3xvYqN4qtiquniF
# 20  spotify:track:3WMj8moIAXJhHsyLaqIIHI
# 21  spotify:track:3cBsEDNhFI9E82vPj3kvi3
# 22  spotify:track:7712gjoih4QoDbXpljEk21
# 23  spotify:track:5kiZGSxgqPdv6rbqL9THdd
# 24  spotify:track:1IHWl5LamUGEuP4ozKQSXZ
# 25  spotify:track:1PckUlxKqWQs3RlWXVBLw3
# 26  spotify:track:28n8z9IQKyjMPxmvYMBqZa
# 27  spotify:track:1qEmFfgcLObUfQm0j1W2CK
# 28  spotify:track:1xzi1Jcr7mEi9K2RfzLOqS
# 29  spotify:track:200x8ONbPfFzByUr3fVz46
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/0V3wPSX9ygBn...
# 1   https://api.spotify.com/v1/tracks/5jQI2r1Rdgtu...
# 2   https://api.spotify.com/v1/tracks/3eX0NZfLtGzo...
# 3   https://api.spotify.com/v1/tracks/3rWDp9tBPQR9...
# 4   https://api.spotify.com/v1/tracks/0jvo9CjnbR0l...
# 5   https://api.spotify.com/v1/tracks/6C7OF1Jal7Yk...
# 6   https://api.spotify.com/v1/tracks/7KokYm8cMIXC...
# 7   https://api.spotify.com/v1/tracks/1xwAWUI6Dj0W...
# 8   https://api.spotify.com/v1/tracks/5CM4UuQ9Gnd6...
# 9   https://api.spotify.com/v1/tracks/56hioFjQ0DXr...
# 10  https://api.spotify.com/v1/tracks/43q586vP8gGk...
# 11  https://api.spotify.com/v1/tracks/3zmwONxswBAz...
# 12  https://api.spotify.com/v1/tracks/4LRPiXqCikLl...
# 13  https://api.spotify.com/v1/tracks/4h9wh7iOZ0GG...
# 14  https://api.spotify.com/v1/tracks/5uU1uuyaUIBO...
# 15  https://api.spotify.com/v1/tracks/0BiqmkasE5Fd...
# 16  https://api.spotify.com/v1/tracks/4C6Uex2ILwJi...
# 17  https://api.spotify.com/v1/tracks/5IgjP7X4th6n...
# 18  https://api.spotify.com/v1/tracks/3UMrglJeju5y...
# 19  https://api.spotify.com/v1/tracks/0hquQWY3xvYq...
# 20  https://api.spotify.com/v1/tracks/3WMj8moIAXJh...
# 21  https://api.spotify.com/v1/tracks/3cBsEDNhFI9E...
# 22  https://api.spotify.com/v1/tracks/7712gjoih4Qo...
# 23  https://api.spotify.com/v1/tracks/5kiZGSxgqPdv...
# 24  https://api.spotify.com/v1/tracks/1IHWl5LamUGE...
# 25  https://api.spotify.com/v1/tracks/1PckUlxKqWQs...
# 26  https://api.spotify.com/v1/tracks/28n8z9IQKyjM...
# 27  https://api.spotify.com/v1/tracks/1qEmFfgcLObU...
# 28  https://api.spotify.com/v1/tracks/1xzi1Jcr7mEi...
# 29  https://api.spotify.com/v1/tracks/200x8ONbPfFz...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/0V3w...    200690.0
# 1   https://api.spotify.com/v1/audio-analysis/5jQI...    202396.0
# 2   https://api.spotify.com/v1/audio-analysis/3eX0...    218271.0
# 3   https://api.spotify.com/v1/audio-analysis/3rWD...    174783.0
# 4   https://api.spotify.com/v1/audio-analysis/0jvo...    194166.0
# 5   https://api.spotify.com/v1/audio-analysis/6C7O...    210557.0
# 6   https://api.spotify.com/v1/audio-analysis/7Kok...    204852.0
# 7   https://api.spotify.com/v1/audio-analysis/1xwA...    164801.0
# 8   https://api.spotify.com/v1/audio-analysis/5CM4...    232115.0
# 9   https://api.spotify.com/v1/audio-analysis/56hi...    191039.0
# 10  https://api.spotify.com/v1/audio-analysis/43q5...    247962.0
# 11  https://api.spotify.com/v1/audio-analysis/3zmw...    188497.0
# 12  https://api.spotify.com/v1/audio-analysis/4LRP...    167303.0
# 13  https://api.spotify.com/v1/audio-analysis/4h9w...    148486.0
# 14  https://api.spotify.com/v1/audio-analysis/5uU1...    157478.0
# 15  https://api.spotify.com/v1/audio-analysis/0Biq...    218503.0
# 16  https://api.spotify.com/v1/audio-analysis/4C6U...    170977.0
# 17  https://api.spotify.com/v1/audio-analysis/5Igj...    184613.0
# 18  https://api.spotify.com/v1/audio-analysis/3UMr...    240356.0
# 19  https://api.spotify.com/v1/audio-analysis/0hqu...    182907.0
# 20  https://api.spotify.com/v1/audio-analysis/3WMj...    228013.0
# 21  https://api.spotify.com/v1/audio-analysis/3cBs...    178520.0
# 22  https://api.spotify.com/v1/audio-analysis/7712...    196259.0
# 23  https://api.spotify.com/v1/audio-analysis/5kiZ...    231475.0
# 24  https://api.spotify.com/v1/audio-analysis/1IHW...    243717.0
# 25  https://api.spotify.com/v1/audio-analysis/1Pck...    191822.0
# 26  https://api.spotify.com/v1/audio-analysis/28n8...    224427.0
# 27  https://api.spotify.com/v1/audio-analysis/1qEm...    177955.0
# 28  https://api.spotify.com/v1/audio-analysis/1xzi...    225389.0
# 29  https://api.spotify.com/v1/audio-analysis/200x...    206107.0
#
#    time_signature  hot  gmm_n5_diag
# 0             4.0  1.0          NaN
# 1             4.0  1.0          NaN
# 2             4.0  1.0          NaN
# 3             4.0  1.0          NaN
# 4             4.0  1.0          NaN
# 5             4.0  1.0          NaN
# 6             4.0  1.0          NaN
# 7             4.0  1.0          NaN
# 8             4.0  1.0          NaN
# 9             4.0  1.0          NaN
# 10            4.0  1.0          NaN
# 11            4.0  1.0          NaN
# 12            4.0  1.0          NaN
# 13            4.0  1.0          NaN
# 14            4.0  1.0          NaN
# 15            4.0  1.0          NaN
# 16            4.0  1.0          NaN
# 17            4.0  1.0          NaN
# 18            4.0  1.0          NaN
# 19            4.0  1.0          NaN
# 20            3.0  1.0          NaN
# 21            3.0  1.0          NaN
# 22            4.0  1.0          NaN
# 23            4.0  1.0          NaN
# 24            4.0  1.0          NaN
# 25            4.0  1.0          NaN
# 26            4.0  1.0          NaN
# 27            4.0  1.0          NaN
# 28            4.0  1.0          NaN
# 29            4.0  1.0          NaN
#
# [30 rows x 22 columns]

# %% [markdown]
# #### combining all the clusters from the team members
