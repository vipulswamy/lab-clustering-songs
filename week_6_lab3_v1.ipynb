# %%
import pandas as pd
import numpy as np
from pickle import dump

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
import time

from sklearn.preprocessing import StandardScaler
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def search_song(artist, title):
    '''
    Query spotify API for a given song to obtain its URI.
    
    Args:
        artist: Artist of the song
        title: Song title
    Return:
        On success the URI is returned, on error "invalid"
    '''
    try:
        print(f'Query for "{title}" by "{artist}": ', end='')
        result = sp.search(q=f'track:{title} artist:{artist}', limit=1)
        uri = result['tracks']['items'][0]['uri']
        print(uri)
        return uri
    except:
        print('failed')
        return "invalid"

# %%
def get_audio_features(chunk):
    '''
    Get audiofeatures for given dataframe chunk and return them
    as a dictionary.
    
    Args:
        chunk: Pandas dataframe
    Return:
        Dictionary with audiofeatures
    '''

    d = {'danceability': [],
         'energy': [],
         'key': [],
         'loudness': [],
         'mode': [],
         'speechiness': [],
         'acousticness': [],
         'instrumentalness': [],
         'liveness': [],
         'valence': [],
         'tempo': [],
         'type': [],
         'id': [],
         'uri': [],
         'track_href': [],
         'analysis_url': [],
         'duration_ms': [],
         'time_signature': []
        }
    
    for index, row in chunk.iterrows():

        uri = search_song(row['artist'], row['title'])       
        audio_feat = sp.audio_features(uri)[0]        

        if audio_feat == None:
            # If we couldn't receive the audio features from spotify,
            # just store a 'x' for each feature and drop the song later...
            for key in d:
                d[key].append('x')
        else:        
            d['danceability'].append(audio_feat['danceability'])
            d['energy'].append(audio_feat['energy'])
            d['key'].append(audio_feat['key'])
            d['loudness'].append(audio_feat['loudness'])
            d['mode'].append(audio_feat['mode'])
            d['speechiness'].append(audio_feat['speechiness'])
            d['acousticness'].append(audio_feat['acousticness'])
            d['instrumentalness'].append(audio_feat['instrumentalness'])
            d['liveness'].append(audio_feat['liveness'])
            d['valence'].append(audio_feat['valence'])
            d['tempo'].append(audio_feat['tempo'])
            d['type'].append(audio_feat['type'])
            d['id'].append(audio_feat['id'])
            d['uri'].append(audio_feat['uri'])
            d['track_href'].append(audio_feat['track_href'])
            d['analysis_url'].append(audio_feat['analysis_url'])
            d['duration_ms'].append(audio_feat['duration_ms'])
            d['time_signature'].append(audio_feat['time_signature'])

        time.sleep(0.5)
    return d

# %% [markdown]
# ### Load our song dataset

# %%
songs_df = pd.read_csv('songs.csv')
songs_df
# Out:
#                    artist                           title  danceability  \
# 0            Taylor Swift                       Anti-Hero         0.637
# 1            Taylor Swift                   Lavender Haze         0.733
# 2            Taylor Swift                          Maroon         0.637
# 3            Taylor Swift                   Midnight Rain         0.643
# 4            Taylor Swift                       Bejeweled         0.700
# ...                   ...                             ...           ...
# 2294      Daniel Norgren                 Moonshine Got Me         0.458
# 2295                Dover                    Serenade me          0.524
# 2296                Queen                  I want it all          0.402
# 2297   Sultans of Ping FC             Where's me jumper?          0.395
# 2298        Jorge Cafrune  No soy de aquí ni soy de allá          0.555
#
#       energy  key  loudness  mode  speechiness  acousticness  \
# 0      0.643    4    -6.571     1       0.0519        0.1300
# 1      0.436   10   -10.489     1       0.0800        0.2580
# 2      0.398    7    -8.294     1       0.0564        0.0573
# 3      0.363    0   -11.738     1       0.0767        0.6900
# 4      0.550    7    -9.130     1       0.0653        0.0661
# ...      ...  ...       ...   ...          ...           ...
# 2294   0.497    8    -9.660     1       0.0479        0.7160
# 2295   0.776    5    -6.193     0       0.0404        0.0330
# 2296   0.835   11    -5.734     0       0.0500        0.0287
# 2297   0.914   11    -6.706     0       0.1590        0.0728
# 2298   0.153    1   -11.320     1       0.0419        0.9460
#
#       instrumentalness  ...  valence    tempo            type  \
# 0             0.000002  ...   0.5330   97.008  audio_features
# 1             0.000573  ...   0.0976   96.985  audio_features
# 2             0.000001  ...   0.0374  108.075  audio_features
# 3             0.000052  ...   0.2300  139.865  audio_features
# 4             0.000102  ...   0.4120  164.003  audio_features
# ...                ...  ...      ...      ...             ...
# 2294          0.155000  ...   0.1440  107.748  audio_features
# 2295          0.000022  ...   0.3010  123.622  audio_features
# 2296          0.000003  ...   0.4300   92.029  audio_features
# 2297          0.000000  ...   0.4350  174.284  audio_features
# 2298          0.000001  ...   0.2740  108.427  audio_features
#
#                           id                                   uri  \
# 0     0V3wPSX9ygBnCm8psDIegu  spotify:track:0V3wPSX9ygBnCm8psDIegu
# 1     5jQI2r1RdgtuT8S3iG8zFC  spotify:track:5jQI2r1RdgtuT8S3iG8zFC
# 2     3eX0NZfLtGzoLUxPNvRfqm  spotify:track:3eX0NZfLtGzoLUxPNvRfqm
# 3     3rWDp9tBPQR9z6U5YyRSK4  spotify:track:3rWDp9tBPQR9z6U5YyRSK4
# 4     0jvo9CjnbR0lYUDTSNTMiu  spotify:track:0jvo9CjnbR0lYUDTSNTMiu
# ...                      ...                                   ...
# 2294  6LrxNNCaqssGmyCGi1EPJA  spotify:track:6LrxNNCaqssGmyCGi1EPJA
# 2295  4tzi4VV1vCTZsT4SEKQIKJ  spotify:track:4tzi4VV1vCTZsT4SEKQIKJ
# 2296  5AaGovcNgVcreY5GHmv3u3  spotify:track:5AaGovcNgVcreY5GHmv3u3
# 2297  1PWkvrHtJI1TLfnZDWDf2u  spotify:track:1PWkvrHtJI1TLfnZDWDf2u
# 2298  0jpbBVTdq6njJi9xUq4Mli  spotify:track:0jpbBVTdq6njJi9xUq4Mli
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/0V3wPSX9ygBn...
# 1     https://api.spotify.com/v1/tracks/5jQI2r1Rdgtu...
# 2     https://api.spotify.com/v1/tracks/3eX0NZfLtGzo...
# 3     https://api.spotify.com/v1/tracks/3rWDp9tBPQR9...
# 4     https://api.spotify.com/v1/tracks/0jvo9CjnbR0l...
# ...                                                 ...
# 2294  https://api.spotify.com/v1/tracks/6LrxNNCaqssG...
# 2295  https://api.spotify.com/v1/tracks/4tzi4VV1vCTZ...
# 2296  https://api.spotify.com/v1/tracks/5AaGovcNgVcr...
# 2297  https://api.spotify.com/v1/tracks/1PWkvrHtJI1T...
# 2298  https://api.spotify.com/v1/tracks/0jpbBVTdq6nj...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/0V3w...      200690
# 1     https://api.spotify.com/v1/audio-analysis/5jQI...      202396
# 2     https://api.spotify.com/v1/audio-analysis/3eX0...      218271
# 3     https://api.spotify.com/v1/audio-analysis/3rWD...      174783
# 4     https://api.spotify.com/v1/audio-analysis/0jvo...      194166
# ...                                                 ...         ...
# 2294  https://api.spotify.com/v1/audio-analysis/6Lrx...      531333
# 2295  https://api.spotify.com/v1/audio-analysis/4tzi...      234280
# 2296  https://api.spotify.com/v1/audio-analysis/5AaG...      241253
# 2297  https://api.spotify.com/v1/audio-analysis/1PWk...      189213
# 2298  https://api.spotify.com/v1/audio-analysis/0jpb...      192293
#
#       time_signature  hot
# 0                  4    1
# 1                  4    1
# 2                  4    1
# 3                  4    1
# 4                  4    1
# ...              ...  ...
# 2294               4    0
# 2295               4    0
# 2296               4    0
# 2297               4    0
# 2298               4    0
#
# [2299 rows x 21 columns]

# %% [markdown]
# #### After discussing with the team we opted the following audio- features that would be helpful in clustering the data together :'danceability', 'energy, 'key', 'loudness, speechiness', acousticness', instrumentalness',liveness, 'valence',tempo'

# %% [markdown]
# #### fearing the time elapsed for computations, after much discussion with the team i have decided to create 5 clusters from the songs dataframe

# %% [markdown]
# #### I have selected to create a Gaussian mixtures model and compare it with my team members about their models and dicuss the optimal solution for the same

# %% [markdown]
# I will use the standard scalar to reduce the outliers

# %%
X = songs_df
#drop Artist and title for our consideration from the data frame
X = X.select_dtypes(np.number)
X = X.drop(['mode', 'duration_ms', 'time_signature', 'hot'], axis=1)
#display(X.head())
#display(X.dtypes)
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns) #convert back to df
print()
display(X_scaled_df.head())
# Out:
#    danceability    energy       key  loudness  speechiness  acousticness  \
# 0      0.204679  0.207977 -0.301005  0.647353    -0.143526     -0.634886
# 1      0.794242 -0.693264  1.380674 -0.373939     0.308374     -0.236195
# 2      0.204679 -0.858710  0.539835  0.198225    -0.071157     -0.861331
# 3      0.241527 -1.011093 -1.422125 -0.699511     0.255304      1.109387
# 4      0.591580 -0.196929  0.539835 -0.019693     0.071971     -0.833921
#
#    instrumentalness  liveness   valence     tempo
# 0         -0.324167 -0.282902 -0.285002 -0.794735
# 1         -0.321107 -0.186233 -2.010424 -0.795591
# 2         -0.324171 -0.547132 -2.248987 -0.382965
# 3         -0.323899 -0.456907 -1.485743  0.799844
# 4         -0.323630 -0.611578 -0.764506  1.697947

# %%
X_scaled_df.describe()
# Out:
#        danceability        energy           key      loudness   speechiness  \
# count  2.299000e+03  2.299000e+03  2.299000e+03  2.299000e+03  2.299000e+03
# mean   2.370874e-16 -1.380173e-16 -4.819498e-17 -1.568993e-16 -5.174441e-17
# std    1.000218e+00  1.000218e+00  1.000218e+00  1.000218e+00  1.000218e+00
# min   -3.707318e+00 -2.508808e+00 -1.422125e+00 -7.503691e+00 -9.781725e-01
# 25%   -6.366765e-01 -6.540799e-01 -8.615652e-01 -6.141429e-01 -4.667704e-01
# 50%    1.125599e-01  1.296079e-01 -2.072536e-02  1.132472e-01 -3.365076e-01
# 75%    7.266881e-01  7.913887e-01  8.201145e-01  7.404110e-01 -1.326279e-02
# max    2.304998e+00  1.749229e+00  1.660954e+00  2.149053e+00  1.216068e+01
#
#        acousticness  instrumentalness      liveness       valence  \
# count  2.299000e+03      2.299000e+03  2.299000e+03  2.299000e+03
# mean   1.748155e-17     -6.203051e-17 -4.568382e-17  2.711088e-16
# std    1.000218e+00      1.000218e+00  1.000218e+00  1.000218e+00
# min   -1.039773e+00     -3.241764e-01 -1.118125e+00 -2.397197e+00
# 25%   -8.899865e-01     -3.241764e-01 -6.302673e-01 -7.981902e-01
# 50%   -3.857045e-01     -3.240344e-01 -3.731269e-01  1.073194e-01
# 75%    8.072540e-01     -3.109722e-01  3.615597e-01  8.503525e-01
# max    2.062508e+00      4.952138e+00  5.175690e+00  1.510166e+00
#
#               tempo
# count  2.299000e+03
# mean   4.240724e-16
# std    1.000218e+00
# min   -4.404110e+00
# 25%   -7.052708e-01
# 50%   -4.918159e-02
# 75%    5.097789e-01
# max    3.441242e+00

# %% [markdown]
# #### Gaussian Mixture method assumes that the data is grouped in such a way that resembles gaussian distributions.

# %% [markdown]
# #### Training Methods:
#     1. Diagonal covariance, Tied Covariance
#     2. n_components: 5 and 7 #the number of clusters

# %% [markdown]
# Method1: covariance = 'diag',n_components = 5

# %%
def gmm_n5_diag(X,X_scaled_df):
    gmm = GaussianMixture(n_components=5,init_params ="random", covariance_type='diag')
    gmm.fit(X_scaled_df)
    ygmm_hat1 = gmm.predict(X_scaled_df)
    #ygmm_hat
    X["cluster_1"] = ygmm_hat1
    X.head(10)
    X, y = make_blobs(n_samples=2299,centers=5)
    #X, y = make_blobs(n_samples=2000, centers=5, n_features=10, random_state=2)
    X_plot = pd.DataFrame(X)
    X_plot.columns=["px","X"]
    X_plot["cluster_1"]=y
    X_plot.head(20)
    plt.figure(figsize=(7,7))
    sns.scatterplot(data=X_plot,x="px",y="X",hue="cluster_1",palette=["red","blue","green", "purple","black"])

# %%
gmm_n5_diag(X_scaled_df)

# %%
gmm = GaussianMixture(n_components=5,init_params ="random", covariance_type='diag')

# %%
gmm.fit(X_scaled_df)
# Out:
# GaussianMixture(covariance_type='diag', init_params='random', n_components=5)

# %% [markdown]
# #### saving the scalar

# %%
#gmm_scaled = gmm.fit(X_scaled_df)
#dump(scaler, open('scaler.pkl', 'wb'))

# %% [markdown]
# #### Running the predictions

# %%
ygmm_hat1 = gmm.predict(X_scaled_df)
#ygmm_hat
X["cluster_1"] = ygmm_hat1
X.head(10)
# Out:
#    danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.637   0.643    4    -6.571       0.0519        0.1300
# 1         0.733   0.436   10   -10.489       0.0800        0.2580
# 2         0.637   0.398    7    -8.294       0.0564        0.0573
# 3         0.643   0.363    0   -11.738       0.0767        0.6900
# 4         0.700   0.550    7    -9.130       0.0653        0.0661
# 5         0.751   0.502    7    -8.777       0.1620        0.2260
# 6         0.642   0.620    8    -7.091       0.0666        0.0734
# 7         0.798   0.277    4   -11.096       0.3900        0.1730
# 8         0.686   0.507    1    -7.097       0.0357        0.6260
# 9         0.661   0.352    4   -14.077       0.1170        0.5710
#
#    instrumentalness  liveness  valence    tempo  cluster_1
# 0          0.000002    0.1420   0.5330   97.008          2
# 1          0.000573    0.1570   0.0976   96.985          1
# 2          0.000001    0.1010   0.0374  108.075          2
# 3          0.000052    0.1150   0.2300  139.865          2
# 4          0.000102    0.0910   0.4120  164.003          2
# 5          0.000000    0.2970   0.1120  108.989          1
# 6          0.000000    0.4830   0.0969   90.020          1
# 7          0.000053    0.1210   0.1630   79.846          1
# 8          0.000075    0.3830   0.6900  168.955          1
# 9          0.001470    0.0884   0.1300  125.934          4

# %% [markdown]
# #### Let's plot them to inspect

# %%
X, y = make_blobs(n_samples=2299,centers=5)
#X, y = make_blobs(n_samples=2000, centers=5, n_features=10, random_state=2)

# %%
X_plot = pd.DataFrame(X)
X_plot.columns=["px","X"]
X_plot["cluster_1"]=y
X_plot.head(20)
# Out:
#            px         X  cluster_1
# 0    2.716124 -1.046084          3
# 1   -3.544693 -2.660264          1
# 2   -1.923539 -3.280210          1
# 3   -9.981686  6.281645          2
# 4   -8.610371 -7.083609          4
# 5   -5.170768 -4.439247          1
# 6   -9.618511 -5.331086          4
# 7   -5.122913 -2.657808          1
# 8   -6.354857 -8.097440          4
# 9   -0.281796  0.309022          3
# 10  -1.762411 -3.914682          1
# 11   0.748079  0.600818          3
# 12  -4.725059 -4.755804          1
# 13  -8.713897 -5.424846          4
# 14  -7.577842 -7.077926          4
# 15  -8.664427  5.216990          2
# 16  -8.817069 -5.890696          4
# 17   3.622691 -2.850979          0
# 18 -11.347823  4.246458          2
# 19  -4.248269 -2.857953          1

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=X_plot,x="px",y="X",hue="cluster_1",palette=["red","blue","green", "purple","black"])
# Out:
# <AxesSubplot:xlabel='px', ylabel='X'>

# %% [markdown]
# #### No clear clustering visible. Too crowded. Try again with more centroids

# %% [markdown]
# covariance = 'diag',n_components = 7

# %%
gmm2 = GaussianMixture(n_components=7,init_params ="random", covariance_type='diag')
gmm2.fit(X_scaled_df)
# Out:
# GaussianMixture(covariance_type='diag', init_params='random', n_components=7)

# %%
ygmm_hat2 = gmm.predict(X_scaled_df)
#ygmm_hat
X["cluster_2"] = ygmm_hat2
X.head(20)
# Out:
#     danceability  energy  key  loudness  speechiness  acousticness  \
# 0          0.637   0.643    4    -6.571       0.0519        0.1300
# 1          0.733   0.436   10   -10.489       0.0800        0.2580
# 2          0.637   0.398    7    -8.294       0.0564        0.0573
# 3          0.643   0.363    0   -11.738       0.0767        0.6900
# 4          0.700   0.550    7    -9.130       0.0653        0.0661
# 5          0.751   0.502    7    -8.777       0.1620        0.2260
# 6          0.642   0.620    8    -7.091       0.0666        0.0734
# 7          0.798   0.277    4   -11.096       0.3900        0.1730
# 8          0.686   0.507    1    -7.097       0.0357        0.6260
# 9          0.661   0.352    4   -14.077       0.1170        0.5710
# 10         0.487   0.313    0   -15.434       0.0487        0.7910
# 11         0.334   0.161    0   -14.875       0.0506        0.9670
# 12         0.520   0.731    6    -5.338       0.0557        0.3420
# 13         0.704   0.797    0    -5.927       0.0475        0.0826
# 14         0.731   0.850    9    -4.913       0.0336        0.2520
# 15         0.422   0.235    6   -12.379       0.0568        0.8260
# 16         0.950   0.891    2    -2.653       0.2410        0.0645
# 17         0.733   0.690    9    -5.529       0.0427        0.0635
# 18         0.573   0.741    5    -8.987       0.0353        0.2190
# 19         0.801   0.601    8    -7.574       0.2550        0.0777
#
#     instrumentalness  liveness  valence    tempo  cluster_2
# 0           0.000002    0.1420   0.5330   97.008          3
# 1           0.000573    0.1570   0.0976   96.985          0
# 2           0.000001    0.1010   0.0374  108.075          0
# 3           0.000052    0.1150   0.2300  139.865          0
# 4           0.000102    0.0910   0.4120  164.003          0
# 5           0.000000    0.2970   0.1120  108.989          0
# 6           0.000000    0.4830   0.0969   90.020          0
# 7           0.000053    0.1210   0.1630   79.846          0
# 8           0.000075    0.3830   0.6900  168.955          2
# 9           0.001470    0.0884   0.1300  125.934          0
# 10          0.348000    0.1240   0.1410  110.039          4
# 11          0.000047    0.1150   0.3960  176.747          2
# 12          0.001010    0.3110   0.6620  173.930          2
# 13          0.000745    0.0546   0.8250  139.994          2
# 14          0.000000    0.6050   0.6440  119.706          4
# 15          0.006480    0.1150   0.0680  165.710          0
# 16          0.000018    0.3090   0.9120  133.010          4
# 17          0.000001    0.1050   0.3100  116.992          0
# 18          0.000022    0.0842   0.5540   96.016          0
# 19          0.000032    0.1450   0.7400  159.969          0

# %%
X, y = make_blobs(n_samples=2299, centers=7)
X_plot = pd.DataFrame(X)
X_plot.columns=["px","X"]
X_plot["cluster_2"]=y
X_plot.head(20)
plt.figure(figsize=(7,7))
sns.scatterplot(data=X_plot,x="px",y="X",hue="cluster_2",palette=["red","blue","green","orange","yellow","purple","black"])
# Out:
# <AxesSubplot:xlabel='px', ylabel='X'>

# %% [markdown]
# #### Improve the predictions again with covariance = tied

# %% [markdown]
# covariance = 'tied',n_components = 5

# %%
gmm = GaussianMixture(n_components=5,init_params ="random", covariance_type='tied')
gmm.fit(X_scaled_df)
# Out:
# GaussianMixture(covariance_type='tied', init_params='random', n_components=5)

# %%
ygmm_hat3 = gmm.predict(X_scaled_df)
#ygmm_hat
X["cluster_3"] = ygmm_hat3
X.head(10)
# Out:
#    danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.637   0.643    4    -6.571       0.0519        0.1300
# 1         0.733   0.436   10   -10.489       0.0800        0.2580
# 2         0.637   0.398    7    -8.294       0.0564        0.0573
# 3         0.643   0.363    0   -11.738       0.0767        0.6900
# 4         0.700   0.550    7    -9.130       0.0653        0.0661
# 5         0.751   0.502    7    -8.777       0.1620        0.2260
# 6         0.642   0.620    8    -7.091       0.0666        0.0734
# 7         0.798   0.277    4   -11.096       0.3900        0.1730
# 8         0.686   0.507    1    -7.097       0.0357        0.6260
# 9         0.661   0.352    4   -14.077       0.1170        0.5710
#
#    instrumentalness  liveness  valence    tempo  cluster_3
# 0          0.000002    0.1420   0.5330   97.008          4
# 1          0.000573    0.1570   0.0976   96.985          4
# 2          0.000001    0.1010   0.0374  108.075          4
# 3          0.000052    0.1150   0.2300  139.865          4
# 4          0.000102    0.0910   0.4120  164.003          4
# 5          0.000000    0.2970   0.1120  108.989          4
# 6          0.000000    0.4830   0.0969   90.020          4
# 7          0.000053    0.1210   0.1630   79.846          1
# 8          0.000075    0.3830   0.6900  168.955          4
# 9          0.001470    0.0884   0.1300  125.934          4

# %%
X, y = make_blobs(n_samples=2299,centers=5)
#X, y = make_blobs(n_samples=2000, centers=5, n_features=10, random_state=2)
X_plot = pd.DataFrame(X)
X_plot.columns=["px","X"]
X_plot["cluster_1"]=y
X_plot.head(20)
plt.figure(figsize=(7,7))
sns.scatterplot(data=X_plot,x="px",y="X",hue="cluster_1",palette=["red","blue","green", "purple","black"])

# %% [markdown]
# covariance = 'tied',n_components = 7

# %%
gmm = GaussianMixture(n_components=7,init_params ="random", covariance_type='tied')
gmm.fit(X_scaled_df)
# Out:
# GaussianMixture(covariance_type='tied', init_params='random', n_components=7)

# %%
ygmm_hat4 = gmm.predict(X_scaled_df)
#ygmm_hat
X["cluster_4"] = ygmm_hat4
X.head(30)
# Out:
#     danceability  energy  key  loudness  speechiness  acousticness  \
# 0          0.637   0.643    4    -6.571       0.0519        0.1300
# 1          0.733   0.436   10   -10.489       0.0800        0.2580
# 2          0.637   0.398    7    -8.294       0.0564        0.0573
# 3          0.643   0.363    0   -11.738       0.0767        0.6900
# 4          0.700   0.550    7    -9.130       0.0653        0.0661
# 5          0.751   0.502    7    -8.777       0.1620        0.2260
# 6          0.642   0.620    8    -7.091       0.0666        0.0734
# 7          0.798   0.277    4   -11.096       0.3900        0.1730
# 8          0.686   0.507    1    -7.097       0.0357        0.6260
# 9          0.661   0.352    4   -14.077       0.1170        0.5710
# 10         0.487   0.313    0   -15.434       0.0487        0.7910
# 11         0.334   0.161    0   -14.875       0.0506        0.9670
# 12         0.520   0.731    6    -5.338       0.0557        0.3420
# 13         0.704   0.797    0    -5.927       0.0475        0.0826
# 14         0.731   0.850    9    -4.913       0.0336        0.2520
# 15         0.422   0.235    6   -12.379       0.0568        0.8260
# 16         0.950   0.891    2    -2.653       0.2410        0.0645
# 17         0.733   0.690    9    -5.529       0.0427        0.0635
# 18         0.573   0.741    5    -8.987       0.0353        0.2190
# 19         0.801   0.601    8    -7.574       0.2550        0.0777
# 20         0.369   0.192    4   -12.151       0.0400        0.5550
# 21         0.505   0.657   11    -5.240       0.0318        0.3730
# 22         0.700   0.509    7   -10.547       0.0789        0.1120
# 23         0.646   0.529   10   -10.179       0.0864        0.7230
# 24         0.650   0.715    5    -5.198       0.2530        0.0993
# 25         0.836   0.743   10    -6.305       0.0656        0.0995
# 26         0.608   0.745    1    -4.130       0.0277        0.0226
# 27         0.714   0.728   10    -4.595       0.0468        0.2980
# 28         0.780   0.689    7    -5.668       0.1410        0.0368
# 29         0.607   0.912    8    -3.449       0.0611        0.1240
#
#     instrumentalness  liveness  valence    tempo  cluster_4
# 0           0.000002    0.1420   0.5330   97.008          4
# 1           0.000573    0.1570   0.0976   96.985          4
# 2           0.000001    0.1010   0.0374  108.075          4
# 3           0.000052    0.1150   0.2300  139.865          4
# 4           0.000102    0.0910   0.4120  164.003          3
# 5           0.000000    0.2970   0.1120  108.989          4
# 6           0.000000    0.4830   0.0969   90.020          6
# 7           0.000053    0.1210   0.1630   79.846          4
# 8           0.000075    0.3830   0.6900  168.955          6
# 9           0.001470    0.0884   0.1300  125.934          4
# 10          0.348000    0.1240   0.1410  110.039          3
# 11          0.000047    0.1150   0.3960  176.747          0
# 12          0.001010    0.3110   0.6620  173.930          6
# 13          0.000745    0.0546   0.8250  139.994          3
# 14          0.000000    0.6050   0.6440  119.706          6
# 15          0.006480    0.1150   0.0680  165.710          2
# 16          0.000018    0.3090   0.9120  133.010          6
# 17          0.000001    0.1050   0.3100  116.992          4
# 18          0.000022    0.0842   0.5540   96.016          4
# 19          0.000032    0.1450   0.7400  159.969          6
# 20          0.000008    0.0954   0.1480  175.212          2
# 21          0.001070    0.1260   0.2520  196.000          6
# 22          0.000033    0.1370   0.3450  110.947          4
# 23          0.000000    0.0885   0.7550   87.862          4
# 24          0.000291    0.1260   0.1870  106.672          6
# 25          0.000000    0.3350   0.7220  108.966          6
# 26          0.000006    0.0942   0.4640  102.025          6
# 27          0.000000    0.1060   0.9010  114.996          2
# 28          0.000010    0.0698   0.6420  115.042          4
# 29          0.000000    0.3320   0.7220  134.944          6

# %%
X, y = make_blobs(n_samples=2299, centers=7)
X_plot = pd.DataFrame(X)
X_plot.columns=["px","X"]
X_plot["cluster_2"]=y
X_plot.head(20)
plt.figure(figsize=(7,7))
sns.scatterplot(data=X_plot,x="px",y="X",hue="cluster_2",palette=["red","blue","green","orange","yellow","purple","black"])
# Out:
# <AxesSubplot:xlabel='px', ylabel='X'>
